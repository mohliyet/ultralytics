# %%
from ultralytics import RTDETR, YOLO

# %%
model = RTDETR("rtdetr-chula-parasiteegg.pt")

# %%
# model = YOLO("yolo11_chula-parasiteegg.pt")

# %%
# results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

# Run inference with the RT-DETR-l model on the 'bus.jpg' image
# results = model("https://ultralytics.com/images/bus.jpg")

# %%
predict_results = model.predict(r'C:\Users\M\Documents\LifeLongLearning\ai_projects\datasets\Chula-ParasiteEgg\CP\cal\images', 
                                conf=0.1,
                                iou=0.5,
                                save_txt=True, 
                                save_conf=True,
                                name='chula-parasiteegg_rtdetr_cal')
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# tensor([0.2568, 0.3655])
# tensor([0.4667, 0.5458])
# image 1/1094 C:\Users\M\Documents\LifeLongLearning\ai_projects\datasets\Chula-ParasiteEgg\CP\cal\images\0003.jpg: 640x640 1 Hookworm egg, 1263.0ms
# tensor([0.4550, 0.5552])
# tensor([0.5052, 0.5420])
# image 2/1094 C:\Users\M\Documents\LifeLongLearning\ai_projects\datasets\Chula-ParasiteEgg\CP\cal\images\0005.jpg: 640x640 1 Trichuris trichiura, 1153.8ms
# tensor([0.3835, 0.5830])
# ...
