# %%
from ultralytics import RTDETR

# %%
model = RTDETR("rtdetr-l.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/rtdetr-l.pt to 'rtdetr-l.pt'...
# 100%|██████████| 63.4M/63.4M [00:11<00:00, 5.96MB/s]

# %%
model.info()
# Out:
# rt-detr-l summary: 673 layers, 32,970,476 parameters, 0 gradients
# (673, 32970476, 0, 0.0)

# %%
# results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

# Run inference with the RT-DETR-l model on the 'bus.jpg' image
# results = model("https://ultralytics.com/images/bus.jpg")

# %%
predict_results = model.predict('https://ultralytics.com/images/bus.jpg', save=True, save_txt=True, save_conf=True, name='what_the_fuck_is_this_')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 c:\Users\M\Documents\LifeLongLearning\ai_projects\packages\ultralytics\bus.jpg: 640x640 4 persons, 1 bus, 1 traffic light, 1 fire hydrant, 2 ties, 1207.0ms
# Speed: 8.3ms preprocess, 1207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to c:\Users\M\Documents\LifeLongLearning\ai_projects\packages\ultralytics\runs\detect\what_the_fuck_is_this_
# 1 label saved to c:\Users\M\Documents\LifeLongLearning\ai_projects\packages\ultralytics\runs\detect\what_the_fuck_is_this_\labels
